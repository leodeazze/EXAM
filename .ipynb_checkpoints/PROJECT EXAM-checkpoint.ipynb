# %%
import pandas as pd

# %%
happiness = pd.read_csv("World happiness report 2021.csv")
happiness
# Out:
#          Country  Regional indicator  Ladder score happiness  \
# 0        Finland      Western Europe                   7.842
# 1        Denmark      Western Europe                   7.620
# 2    Switzerland      Western Europe                   7.571
# 3        Iceland      Western Europe                   7.554
# 4    Netherlands      Western Europe                   7.464
# ..           ...                 ...                     ...
# 144      Lesotho  Sub-Saharan Africa                   3.512
# 145     Botswana  Sub-Saharan Africa                   3.467
# 146       Rwanda  Sub-Saharan Africa                   3.415
# 147     Zimbabwe  Sub-Saharan Africa                   3.145
# 148  Afghanistan          South Asia                   2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# ...

# %%
clean_happiness = happiness.drop(happiness.iloc[:, 3:20], axis=1)
clean_happiness = clean_happiness.drop(['Regional indicator'], axis = 1)
clean_happiness = clean_happiness.dropna(axis=0)
clean_happiness
# Out:
#          Country  Ladder score happiness
# 0        Finland                   7.842
# 1        Denmark                   7.620
# 2    Switzerland                   7.571
# 3        Iceland                   7.554
# 4    Netherlands                   7.464
# ..           ...                     ...
# 144      Lesotho                   3.512
# 145     Botswana                   3.467
# 146       Rwanda                   3.415
# 147     Zimbabwe                   3.145
# 148  Afghanistan                   2.523
#
# [149 rows x 2 columns]

# %%
mental_health_and_suicide_rates = pd.read_csv("Mental health and suicide rates.csv")
mental_health_and_suicide_rates
# Out:
#          Country          Sex  2016 suicide rate  2015  2010  2000
# 0    Afghanistan   Both sexes                6.4   6.6   7.4   8.1
# 1    Afghanistan         Male               10.6  10.9  12.5  14.3
# 2    Afghanistan       Female                2.1   2.1   2.1   1.7
# 3        Albania   Both sexes                5.6   5.3   7.7   5.8
# 4        Albania         Male                7.0   6.7   9.5   8.2
# ..           ...          ...                ...   ...   ...   ...
# 544       Zambia         Male               17.5  17.4  17.9  21.9
# 545       Zambia       Female                6.2   6.1   6.2   7.5
# 546     Zimbabwe   Both sexes               19.1  18.9  20.6  21.7
# 547     Zimbabwe         Male               29.1  28.7  32.3  35.5
# 548     Zimbabwe       Female               11.1  11.1  11.1   9.8
#
# [549 rows x 6 columns]

# %%
clean_mental_health_and_suicide_rates = mental_health_and_suicide_rates.drop(['2015', '2010', '2000'], axis=1)
clean_mental_health_and_suicide_rates = clean_mental_health_and_suicide_rates.dropna(axis=0)
clean_mental_health_and_suicide_rates
# Out:
#          Country          Sex  2016 suicide rate
# 0    Afghanistan   Both sexes                6.4
# 1    Afghanistan         Male               10.6
# 2    Afghanistan       Female                2.1
# 3        Albania   Both sexes                5.6
# 4        Albania         Male                7.0
# ..           ...          ...                ...
# 544       Zambia         Male               17.5
# 545       Zambia       Female                6.2
# 546     Zimbabwe   Both sexes               19.1
# 547     Zimbabwe         Male               29.1
# 548     Zimbabwe       Female               11.1
#
# [549 rows x 3 columns]

# %%
fertility = pd.read_csv("Fertility rate.csv")
fertility
# Out:
#           Country Country Code                            Indicator Name  \
# 0           Aruba          ABW  Fertility rate, total (births per woman)
# 1     Afghanistan          AFG  Fertility rate, total (births per woman)
# 2          Angola          AGO  Fertility rate, total (births per woman)
# 3         Albania          ALB  Fertility rate, total (births per woman)
# 4         Andorra          AND  Fertility rate, total (births per woman)
# ..            ...          ...                                       ...
# 259        Kosovo          XKX  Fertility rate, total (births per woman)
# 260   Yemen, Rep.          YEM  Fertility rate, total (births per woman)
# 261  South Africa          ZAF  Fertility rate, total (births per woman)
# 262        Zambia          ZMB  Fertility rate, total (births per woman)
# 263      Zimbabwe          ZWE  Fertility rate, total (births per woman)
#
#      Indicator Code   1960   1961   1962   1963   1964   1965  ...   2007  \
# ...

# %%
clean_fertility = fertility.drop(fertility.iloc[:, 2:60], axis=1)
clean_fertility = clean_fertility.drop(['Country Code'], axis=1)
clean_fertility = clean_fertility.dropna(axis=0)
clean_fertility
# Out:
#           Country  2016 fertility rate
# 0           Aruba             1.800000
# 1     Afghanistan             4.635000
# 2          Angola             5.694000
# 3         Albania             1.713000
# 5      Arab World             3.326532
# ..            ...                  ...
# 259        Kosovo             2.060000
# 260   Yemen, Rep.             3.995000
# 261  South Africa             2.458000
# 262        Zambia             4.981000
# 263      Zimbabwe             3.760000
#
# [246 rows x 2 columns]

# %%
countries = pd.read_csv("Countries of the world.csv")
countries
# Out:
#                                  Country                               Region  \
# 0                           Afghanistan         ASIA (EX. NEAR EAST)
# 1                               Albania   EASTERN EUROPE
# 2                               Algeria   NORTHERN AFRICA
# 3                        American Samoa   OCEANIA
# 4                               Andorra   WESTERN EUROPE
# ..                                   ...                                  ...
# 224                               Yemen   NEAR EAST
# 225                              Zambia   SUB-SAHARAN AFRICA
# 226                            Zimbabwe   SUB-SAHARAN AFRICA
# 227  </pre></body></html>Xtext/csvUUTF-8                                  NaN
# 228                                  NaN                                  NaN
#
#      Population  Area (sq. mi.) Pop. Density (per sq. mi.)  \
# 0    31056997.0        647500.0                       48,0
# 1     3581655.0         28748.0                      124,6
# ...

# %%
clean_countries = countries.drop(countries.iloc[:, 1:8], axis=1)
clean_countries = clean_countries.drop(clean_countries.iloc[:, 2:13], axis=1)
clean_countries = clean_countries.dropna(axis=0)
clean_countries
# Out:
#                 Country  GDP ($ per capita)
# 0          Afghanistan                700.0
# 1              Albania               4500.0
# 2              Algeria               6000.0
# 3       American Samoa               8000.0
# 4              Andorra              19000.0
# ..                  ...                 ...
# 221  Wallis and Futuna               3700.0
# 222          West Bank                800.0
# 224              Yemen                800.0
# 225             Zambia                800.0
# 226           Zimbabwe               1900.0
#
# [226 rows x 2 columns]

# %%
finaldata= clean_happiness.merge(clean_mental_health_and_suicide_rates, left_on="Country", right_on="Country")
finaldata
# Out:
#          Country  Ladder score happiness          Sex  2016 suicide rate
# 0        Finland                   7.842   Both sexes               13.8
# 1        Finland                   7.842         Male               20.8
# 2        Finland                   7.842       Female                6.8
# 3        Denmark                   7.620   Both sexes                9.2
# 4        Denmark                   7.620         Male               13.2
# ..           ...                     ...          ...                ...
# 379     Zimbabwe                   3.145         Male               29.1
# 380     Zimbabwe                   3.145       Female               11.1
# 381  Afghanistan                   2.523   Both sexes                6.4
# 382  Afghanistan                   2.523         Male               10.6
# 383  Afghanistan                   2.523       Female                2.1
#
# [384 rows x 4 columns]

# %%
finaldata.isna().sum()
# Out:
# Country                   0
# Ladder score happiness    0
# Sex                       0
# 2016 suicide rate         0
# dtype: int64
